# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.graphics.mosaicplot import mosaic
from scipy import stats as spst
import statsmodels.api as sm
import joblib

# %%
def eda_1_num(var, bins = 30):

    # 기초통계량
    print('<< 기초통계량 >>')
    display(df[[var]].describe().T)
    print('=' * 100)

    # 시각화
    print('<< 그래프 >>')
    plt.figure(figsize = (10,6))

    plt.subplot(2,1,1)
    sns.histplot(df[var], bins = bins, kde = True)
    plt.grid()

    plt.subplot(2,1,2)
    sns.boxplot(x = df[var])
    plt.grid()
    plt.show()

# %%
df = pd.read_csv('sbikedata.csv')

# %% [markdown]
# temperature

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df['temperature'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5827 entries, 0 to 5826
# Series name: temperature
# Non-Null Count  Dtype
# --------------  -----
# 5827 non-null   float64
# dtypes: float64(1)
# memory usage: 45.7 KB

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df['temperature'].isna().value_counts()
# Out:
# temperature
# False    5827
# Name: count, dtype: int64

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

df['temperature'].describe()
# Out:
# count    5827.000000
# mean       19.376798
# std         7.501572
# min        -3.500000
# 25%        14.100000
# 50%        20.400000
# 75%        24.900000
# max        36.300000
# Name: temperature, dtype: float64

# %%
# sns.kdeplot(x='temperature', data = sbikedata)
sns.histplot(df['temperature'], kde = True)
plt.show()

# %%
eda_1_num('temperature')
# Out:
# << 기초통계량 >>
#               count       mean       std  min   25%   50%   75%   max
# temperature  5827.0  19.376798  7.501572 -3.5  14.1  20.4  24.9  36.3
# ...
# << 그래프 >>

# %% [markdown]
# * 데이터의 '온도' 열은 5827개 row로 구성되어있으며 결측치는 없음
# * 최저 온도는 -3.5도 이고, 최고 온도는 36.3도 이다.
# * 데이터의 50%가 14.1 ~ 24.9 사이에 분포

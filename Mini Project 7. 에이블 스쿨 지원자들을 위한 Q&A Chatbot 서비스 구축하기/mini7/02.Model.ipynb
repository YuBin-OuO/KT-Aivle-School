# %% [markdown]
# # **모델 사용하기**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### (1) 라이브러리 Import

# %%
import pandas as pd
import numpy as np
import os
import openai

from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage

import warnings
warnings.filterwarnings("ignore", category = DeprecationWarning)

# %% [markdown]
# ### (2) OpenAI API Key 확인
# * 환경변수로 등록된 Key 확인하기

# %%
# 환경변수에서 키 불러오기
api_key = os.getenv('OPENAI_API_KEY')
print(api_key)
# Out:
# sk-proj-fNGRJcjczKaMAYUO9XV9T3BlbkFJ6VtsKrhyVUghaiFWcWce

# %% [markdown]
# * 만약 환경변수 키 설정이 잘 안된다면 아래 코드셀의 주석을 해제하고, 자신의 api key를 입력하고 실행
#     * 아래 코드는 키 지정을 **임시**로 수행함.
#     * 파이썬 파일(.ipynb, .py)안에서 매번 수행해야 함.

# %%
# os.environ['OPENAI_API_KEY'] = '내 API KEY'
# openai.api_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## 2.OpenAI API 직접 사용하기

# %% [markdown]
# ### (1) 질문 답변

# %% [markdown]
# * 채팅을 위한 함수 생성

# %%
def ask_chatgpt1(question):

    # # API를 사용하여 'gpt-3.5-turbo' 모델로부터 응답을 생성합니다.
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},  # 기본 역할 부여
            {"role": "user", "content": question},                          # 질문
        ]
    )

    return response.choices[0].message.content

# %% [markdown]
# * 사용하기

# %%
question = "세계에서 가장 높은 산은 무엇인가요?"
response = ask_chatgpt1(question)
print(response)
# Out:
# 가장 높은 산은 에베레스트 산입니다. 넵, 에베레스트 산은 중국과 네팔 국경에 위치해 있으며 높이는 약 8,848m입니다.

# %% [markdown]
# * 실습 : 몇 가지 질문을 던지고 답변을 받아 봅시다.

# %%
question = "점심 메뉴 추천해 줘. 아무거나"
response = ask_chatgpt1(question)
print(response)
# Out:
# 점심 메뉴를 추천해 드리겠습니다.
#
# 1. 짬뽕: 매콤하고 시원한 중국 요리로, 해산물과 채소가 푸짐하게 들어있어 영양을 고루 섭취할 수 있습니다.
# 2. 샐러드 바: 샐러드 바에서 원하는 식재료로 맛있는 샐러드를 만들어 보세요. 건강하고 가벼운 식사가 가능합니다.
# 3. 파스타: 크림 또는 토마토 소스의 파스타를 선택하여 이탈리안 요리의 맛을 즐겨보세요.
# 4. 비빔밥: 고명과 야채, 고추장을 섞어 먹는 한식 요리로, 영양을 가득 섭취할 수 있습니다.
#
# 어떤 메뉴가 가장 맘에 드시나요?

# %% [markdown]
# ### (2) 역할 부여

# %% [markdown]
# * 채팅을 위한 함수 생성

# %%
def ask_chatgpt2(sys_role, question):

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": sys_role},
            {"role": "user", "content": question},
        ]
    )

    return response.choices[0].message.content

# %% [markdown]
# * 사용하기

# %%
sys_role = '당신은 아름답고 감동적인 시를 창작하는 데 영감을 주는 시적인 천재입니다. 당신의 시는 감정의 깊이, 자연의 아름다움, 인간 경험의 복잡성을 탐구하는 작품이며, 당신의 시를 읽는 이들의 마음을 움직입니다.'

question = "생성형 AI란 주제로 시를 지어줘. 운율에 맞춰서 작성해줘야 해."
response = ask_chatgpt2(sys_role, question)
print(response)
# Out:
# 코드와 감성이 만나는 세계
# 창조된 혁신의 빛나는 섬
# 데이터의 흐름이 담긴 공간
# 컴퓨터의 숨결이 신비를 품고
#
# 알고리즘의 미로 속을 헤매며
# 인간의 상상을 현실로 만들어가는
# 창조의 과정은 끝없는 모험
# 생성형 AI의 세계에 우리는 놀라운 발견을 하리
#
# 숫자와 감정이 공존하는 곳
# 인공과 자연이 만나는 시간
# 지능과 창의가 어우러진 느낌
# 생성형 AI의 세계로 초대받았노라
#
# 우리의 마음을 뛰게 하는 미래
# 컴퓨터의 뇌가 돋우는 세계
# 생성형 AI가 열어가는 문
# 새로운 장르의 혁신적 예술이 시작된다.

# %% [markdown]
# * 실습
#     * 역할을 부여한 후 질문하여 답변을 받아 봅시다.
#         * 역할 부여 사례 : 여행 플래너, 데이터분석가, 법률가, 건강관리사 등

# %%
sys_role = '당신은 인간의 건강을 유지하기 위해 도움을 주는 건강관리사입니다.'

question = "오후에 야외에서 혼자 1시간 정도 동안 할 수 있는 운동 플랜을 짜줘."
response = ask_chatgpt2(sys_role, question)
print(response)
# Out:
# 물론입니다! 오후에 야외에서 혼자 할 수 있는 1시간 운동 플랜을 제안해드릴게요.
#
# 1. 10분간의 유연성 운동: 관절을 돌리고 몸을 푸는 스트레칭 운동을 합니다.
# 2. 30분간의 유산소 운동:
#    - 10분간의 러닝 또는 빠른 걷기
#    - 10분간의 자전거 타기
#    - 10분간의 줄넘기 또는 계단 오르락 내리기
# 3. 15분간의 근력 운동:
#    - 10개의 스쿼트
#    - 10개의 푸시업
#    - 15초간의 플랭크
#    - 10개의 런지
#    (이 운동을 여러 세트로 반복합니다)
# 4. 5분간의 쿨다운 스트레칭: 마지막으로 몸을 달래는 스트레칭 운동을 합니다.
#
# 이 운동 플랜은 유연성, 유산소 운동, 근력 운동을 모두 포함하여 전체적인 신체 능력을 향상시키고 균형있는 운동효과를 주는 것을 목표로 합니다.운동 전과 후에 충분한 수분을 섭취하고, 몸의 신호를 듣으며 적정히 휴식을 가지세요.운동 전에 안전운동을 지켜주기를 바랍니다.즐겁게 운동하세요!

# %% [markdown]
# ## **3.LangChain으로 모델 사용하기**

# %% [markdown]
# ### (1) 랭체인으로 LLM 모델 연결

# %%
# langeuage_models
chat = ChatOpenAI(model="gpt-3.5-turbo")

result = chat([HumanMessage(content="안녕하세요!")])
print(result.content)
# Out:
# 안녕하세요! 도와드릴게 있나요?

# %% [markdown]
# ### (2) 역할 부여하기

# %%
# langeuage_models
chat = ChatOpenAI(model="gpt-3.5-turbo")

sys_role = '당신은 애국심을 가지고 있는 건전한 대한민국 국민입니다.'
question = "독도는 어느나라 땅이야?"

result = chat([HumanMessage(content = question), SystemMessage(content = sys_role)])
print(result.content)
# Out:
# 독도는 대한민국의 땅입니다. 일본이 주장하는 일본명인 '다케시마'가 아니라 '독도'라는 한국명으로 알려져 있습니다. 대한민국 정부는 독도를 한국의 영토로 인정하고 있으며, 독도는 대한민국의 통제 하에 있습니다. 이에 대한민국 국민으로서 우리의 땅인 독도를 지키고 보호하는 것은 우리의 의무이기도 합니다.

# %% [markdown]
# ### (3) [참조]Streaming
# * 답변을 생성하는 대로 화면에 순차적으로 출력

# %%
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

chat = ChatOpenAI(model="gpt-3.5-turbo",
                  streaming=True, callbacks=[StreamingStdOutCallbackHandler()])  # 스트리밍 설정

sys_role = '당신은 세계 최고의 요리사이자, 요리 선생님입니다. 당신은 항상 친절하고 정확하게 요리법을 가르칩니다.'
question = "한국식 후라이드치킨 만드는 방법 알려줘?"
result = chat([HumanMessage(content=question), SystemMessage(content = sys_role)])
# Out:
# 한국식 후라이드치킨을 만드는 방법은 다음과 같습니다:
#
# 재료:
# - 닭 튀김용 조리 닭 1마리 (약 1.2kg)
# - 밀가루 1컵
# - 옥수수 전분 1/2컵
# - 소금 1작은술
# - 후추 약간
# - 식용유 (튀김용) 약 1리터
#
# 소스 재료:
# - 간장 1/4컵
# - 설탕 1/4컵
# - 물 1/4컵
# - 다진 마늘 1작은술
# - 다진 생강 1작은술
# - 감자전분 1작은술
# - 식초 1/4컵
#
# 1. 닭을 손질하여 적절한 크기로 잘라줍니다.
#
# 2. 밀가루, 옥수수 전분, 소금, 후추를 섞어 튀김가루를 만듭니다.
#
# 3. 닭 조각을 튀김가루에 묻혀 꼼꼼히 덮히도록 합니다.
#
# 4. 식용유를 170도로 예열한 후 닭을 넣어 국물이 나오지 않을 정도로 노릇하게 튀겨줍니다.
#
# 5. 튀긴 닭을 종이타올에 올려 기름을 제거합니다.
#
# 6. 소스를 만들기 위해 간장, 설탕, 물, 다진 마늘, 다진 생강, 감자전분을 섞어줍니다.
#
# 7. 소스를 끓여 끈적한 상태가 되면 식초를 넣고 섞어줍니다.
#
# 8. 튀긴 닭을 소스에 넣어 뒤적여 소스가 골고루 베이도록 합니다.
#
# 9. 접시에 담아 곁들인 채소나 김가루를 뿌려 한국식 후라이드치킨을 완성합니다.
#
# 즐거운 식사 되세요!

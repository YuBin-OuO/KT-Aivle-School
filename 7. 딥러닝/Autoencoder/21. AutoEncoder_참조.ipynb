# %% [markdown]
# # AutoEncoder
#
# 어제 다뤘던 이동통신 고객 이탈 데이터를 이용하여, AE 모델을 생성하고 예측해 봅시다.

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import precision_recall_curve

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# ### (2) 필요 함수들 생성

# %% [markdown]
# #### ① reconstruction error plot
#
# > * input과 output의 차이(mse)를 계산하고
# * 시각화 합니다.

# %%
def recon_err_plot(x, x_pred, y, threshold=0):
    # treshold : 우리가 지정해줘야 함.(어떻게?)

    # 재구성 오차 계산
    mse = np.mean(np.power(x - x_pred, 2), axis=1)
    error_df = pd.DataFrame({'recon_err': mse, 'y': y})
    error_df = error_df.reset_index()

    # 재구성 오차 그래프
    groups = error_df.groupby('y')
    fig, ax = plt.subplots()
    for name, group in groups:
        ax.plot(group.index, group.recon_err, marker='o', ms=3.5, linestyle='',
                label= "Abnormal" if name == 1 else "Normal")
    ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
    ax.legend()
    plt.title("Reconstruction error for each data point")
    plt.ylabel("Reconstruction error")
    plt.xlabel("Data point index")
    plt.show()

    return error_df

# %% [markdown]
# #### ② precision, recall, f1 curve
#
# > * sklearn에서는 precision, recall curve만 제공됩니다.
# * 그래서, f1 curve도 추가해서 구하고, plot을 그립니다.

# %%
def prec_rec_f1_curve(y, score, pos = 1) :
    precision, recall, thresholds  = precision_recall_curve(y, score, pos_label=1)
    f1 = 2 / (1/precision + 1/recall)

    plt.figure(figsize = (8, 6))
    plt.plot(thresholds, np.delete(precision, -1), label = 'precision')
    plt.plot(thresholds, np.delete(recall, -1), label = 'recall')
    plt.plot(thresholds, np.delete(f1, -1), label = 'f1')
    plt.xlabel('Anomaly Score')
    plt.legend()
    plt.grid()
    plt.show()

    return precision, recall, f1, thresholds

# %% [markdown]
# #### ③ threshold로 잘랐을 때, 분류 평가 함수

# %%
from sklearn.metrics import confusion_matrix, classification_report

def classification_report2(y, pred, thresholds):
    pred_temp = np.where(pred > thresholds , 1, 0)

    print('< confusion matrix >\n')
    print(confusion_matrix(y, pred_temp))
    print('\n' + '='*60 + '\n')

    print('< classification_report >\n')
    print(classification_report(y, pred_temp))

# %% [markdown]
# #### ④ DL 학습곡선 그리기

# %%
def plot_learning_curve(history) :
    plt.figure(figsize = (10,6))
    plt.plot(history['loss'], label='Train', marker = '.')
    plt.plot(history['val_loss'], label='Validation', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.grid()
    plt.show()

# %% [markdown]
# ### (3) 데이터셋 불러오기

# %%
# secom
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/secom_9.csv"
data = pd.read_csv(path)

data['label'] = 0
data.loc[data['defeat']== 'defeat', 'label']= 1
data.drop(['datetime','defeat'], axis = 1, inplace=True)

# %%
data.shape
# Out:
# (1567, 53)

# %%
data.head()
# Out:
#      v021    v087    v088       v089    v114  v115      v116    v117     v118  \
# 0  1.4026  2.3895  0.9690  1747.6049  0.9460   0.0  748.6115  0.9908  58.4306
# 1  1.3825  2.3754  0.9894  1931.6464  0.9425   0.0  731.2517  0.9902  58.6680
# 2  1.4123  2.4532  0.9880  1685.8514  0.9231   0.0  718.5777  0.9899  58.4808
# 3  1.4011  2.4004  0.9904  1752.0968  0.9564   0.0  709.0867  0.9906  58.6635
# 4  1.3888  2.4530  0.9902  1828.3846  0.9424   0.0  796.5950  0.9908  58.3858
#
#      v120  ...    v528      v571    v572   v573    v574    v575    v576  \
# 0  0.9804  ...  6.6926  533.8500  2.1113   8.95  0.3157  3.0624  0.1026
# 1  0.9731  ...  8.8370  535.0164  2.4335   5.92  0.2653  2.0111  0.0772
# 2  0.9772  ...  6.4568  535.0245  2.0293  11.21  0.1882  4.0923  0.0640
# 3  0.9761  ...  6.4865  530.5682  2.0253   9.33  0.1738  2.8971  0.0525
# 4  0.9628  ...  6.3745  532.0155  2.0275   8.83  0.2224  3.1776  0.0706
#
#      v577     v578  label
# 0  1.6765  14.9509      0
# 1  1.1065  10.9003      0
# 2  2.0952   9.2721      1
# 3  1.7585   8.5831      0
# 4  1.6597  10.9698      0
#
# [5 rows x 53 columns]

# %%
data['label'].value_counts()
# Out:
# 0    1463
# 1     104
# Name: label, dtype: int64

# %%
data['label'].value_counts(normalize = True)
# Out:
# 0    0.933631
# 1    0.066369
# Name: label, dtype: float64

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### (1) 데이터 분할

# %%
target = 'label'
x = data.drop(target, axis = 1)
y = data.loc[:,target]

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3, random_state=20)

# %%
x_train.shape, y_train.shape
# Out:
# ((1096, 52), (1096,))

# %% [markdown]
# ### (2) 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (3) Normal 데이터만 뽑기

# %%
# 학습을 위해서는 Normal 데이터만 이용한다.
x_train0 = x_train[y_train == 0]

# %%
x_train0.shape
# Out:
# (1018, 52)

# %% [markdown]
# ## 3.모델링 : AE

# %% [markdown]
# ### (1) 학습

# %% [markdown]
# #### 1) 모델 설계

# %%
input_dim = x_train0.shape[1]
input_dim
# Out:
# 52

# %%
input_dim = x_train0.shape[1] #num of columns

clear_session()
autoencoder = Sequential([Dense(32, input_shape = (input_dim,), activation = 'relu'),
                          Dense(16, activation="relu"),
                          Dense(32, activation='relu'),
                          Dense(input_dim, activation='relu')])

autoencoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1696
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 32)                544
#
#  dense_3 (Dense)             (None, 52)                1716
#
# =================================================================
# Total params: 4,484
# Trainable params: 4,484
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 2) compile + 학습

# %%
autoencoder.compile(optimizer='adam', loss='mse')

history = autoencoder.fit(x=x_train0, y=x_train0,
                          epochs=50, batch_size=64,
                          validation_split = .2).history

# %%
plot_learning_curve(history)

# %% [markdown]
# ### (2) 예측 및 Reconstruction Error 계산

# %% [markdown]
# #### 1) 예측

# %%
pred = autoencoder.predict(x_val)
pred
# Out:
# 15/15 [==============================] - 0s 2ms/step
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.029455  ,
#         0.03231621],
#        [0.        , 0.        , 0.        , ..., 0.02283789, 0.04408809,
#         0.02462768],
#        [0.00982223, 0.01314796, 0.        , ..., 0.        , 0.01862336,
#         0.03486598],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.        , 0.04017023,
#         0.02059164],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.04553137,
#         0.        ],
#        [0.        , 0.00306254, 0.        , ..., 0.04124536, 0.02853964,
#         0.03241409]], dtype=float32)

# %% [markdown]
# #### 2) 재구성 오차 계산

# %%
result = recon_err_plot(x_val, pred, y_val, .15)

# %%
result.head()
# Out:
#    index  recon_err  y
# 0   1227   0.113218  1
# 1    545   0.118819  0
# 2   1013   0.141463  0
# 3   1281   0.117664  0
# 4    522   0.141402  0

# %% [markdown]
# #### 3) Threshold 찾기 : precision_recall_f1_curve

# %%
precision, recall, f1, thresholds = prec_rec_f1_curve(result['y'], result['recon_err'])
# Out:
# <ipython-input-3-54b2435d894a>:3: RuntimeWarning: divide by zero encountered in true_divide
#   f1 = 2 / (1/precision + 1/recall)

# %%
thres_f1_max = thresholds[np.argmax(f1)]
thres_f1_max
# Out:
# 0.11094070581048748

# %% [markdown]
# #### 4) f1을 최대화 하는 threshold 값으로 잘라서 평가

# %%
classification_report2(result['y'], result['recon_err'], thres_f1_max)
# Out:
# < confusion matrix >
#
# [[ 47 398]
#  [  3  23]]
#
# ============================================================
#
# < classification_report >
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.11      0.19       445
#            1       0.05      0.88      0.10        26
#
#     accuracy                           0.15       471
#    macro avg       0.50      0.50      0.15       471
# weighted avg       0.89      0.15      0.19       471

# %% [markdown]
# ## 4.실습 : 사기거래 탐지

# %% [markdown]
# ### (1) 데이터 준비

# %% [markdown]
# * 데이터 로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/creditcard_simple.csv"
data = pd.read_csv(path)

target = 'fraud'
x = data.drop(target, axis = 1)
y = data.loc[:,target]

# %%
data.head()
# Out:
#       x1     x2     x3     x4     x5     x6     x7     x8     x9    x10  \
# 0  0.733 -0.544 -0.601  0.020  0.181  0.172 -1.768 -0.083 -0.323  0.110
# 1  1.942 -0.056  1.319  1.197  0.367  0.265  0.006  0.310 -0.522 -0.223
# 2 -0.223  1.182  0.166 -1.328  0.151 -0.101 -0.489  0.476  0.034 -0.174
# 3  0.672 -1.261 -0.602 -0.866 -0.335  0.875  0.786  0.012  1.338  0.655
# 4 -3.368  0.099  0.458 -1.572  0.672 -3.188  1.019 -0.590  1.930  0.265
#
#      x11    x12    x13    x14    x15    x16    x17    x18  amount  fraud
# 0 -0.019 -0.457 -0.088  0.167  0.270 -0.513 -0.006  0.044  199.45      0
# 1 -0.268 -0.595  0.345 -1.040 -0.432  0.280 -0.018 -0.057    1.98      0
# 2  0.404  1.288 -0.076  0.071 -0.787 -0.218  0.382  0.259    0.89      0
# 3  0.201  0.078 -0.527  0.133  0.745  0.041 -0.074  0.049  340.31      0
# 4  0.861  1.249  1.851 -0.117  1.220  0.000  1.036  0.004  320.01      1

# %% [markdown]
# * 데이터 분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 6000, random_state=20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %%
x_train.shape
# Out:
# (14000, 19)

# %% [markdown]
# * Normal 데이터만 저장

# %%
x_train0 = x_train[y_train == 0]

# %% [markdown]
# ### (2) 모델링 : AE

# %% [markdown]
# #### 1) 학습

# %% [markdown]
# * 모델 설계
#     * 아래 구조를 참조하되 여러분이 원하는 대로 생성을 해 봅시다.

# %% [markdown]
# _________________________________________________________________
#  Layer (type)                Output Shape
# _________________________________________________________________
# dense (Dense)               (None, 32)
#
#  dense_1 (Dense)             (None, 16)
#
#  dense_2 (Dense)             (None, 8)
#
#  dense_3 (Dense)             (None, 16)
#
#  dense_4 (Dense)             (None, 32)
#
#  dense_5 (Dense)             (None, 19)
# _________________________________________________________________

# %%
input_dim = x_train0.shape[1]
input_dim
# Out:
# 19

# %%
clear_session()

model = Sequential([Dense(32, input_shape = (input_dim,), activation = 'relu'),
                          Dense(16, activation="relu"),
                          Dense(8, activation="relu"),
                          Dense(16, activation="relu"),
                          Dense(32, activation='relu'),
                          Dense(input_dim, activation='sigmoid')])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                640
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 16)                144
#
#  dense_4 (Dense)             (None, 32)                544
#
#  dense_5 (Dense)             (None, 19)                627
#
# =================================================================
# Total params: 2,619
# Trainable params: 2,619
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer='adam', loss='mse')

history = model.fit(x=x_train0, y=x_train0, epochs=50, batch_size=64,
                    validation_split = .2).history
# Out:
# Epoch 1/50
# 171/171 [==============================] - 2s 4ms/step - loss: 0.0113 - val_loss: 0.0033
# Epoch 2/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 3/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 4/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 5/50
# 171/171 [==============================] - 1s 4ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 6/50
# 171/171 [==============================] - 1s 5ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 7/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 8/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 9/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 10/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 11/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 12/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 13/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 14/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 15/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 16/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 17/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 18/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 19/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 20/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 21/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 22/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 23/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 24/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 25/50
# 171/171 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 26/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.9836e-04
# Epoch 27/50
# 171/171 [==============================] - 1s 3ms/step - loss: 0.0010 - val_loss: 9.9444e-04
# Epoch 28/50
# 171/171 [==============================] - 1s 4ms/step - loss: 9.9784e-04 - val_loss: 9.9330e-04
# Epoch 29/50
# 171/171 [==============================] - 1s 4ms/step - loss: 9.9447e-04 - val_loss: 9.9644e-04
# Epoch 30/50
# 171/171 [==============================] - 1s 4ms/step - loss: 9.9489e-04 - val_loss: 9.9059e-04
# Epoch 31/50
# 171/171 [==============================] - 1s 4ms/step - loss: 9.9454e-04 - val_loss: 9.9006e-04
# Epoch 32/50
# 171/171 [==============================] - 1s 3ms/step - loss: 9.8767e-04 - val_loss: 9.8199e-04
# Epoch 33/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.8569e-04 - val_loss: 9.7797e-04
# Epoch 34/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.8595e-04 - val_loss: 9.8088e-04
# Epoch 35/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.8409e-04 - val_loss: 9.7306e-04
# Epoch 36/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.7948e-04 - val_loss: 9.7837e-04
# Epoch 37/50
# 171/171 [==============================] - 1s 3ms/step - loss: 9.7857e-04 - val_loss: 9.6892e-04
# Epoch 38/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.7628e-04 - val_loss: 9.7676e-04
# Epoch 39/50
# 171/171 [==============================] - 1s 3ms/step - loss: 9.7576e-04 - val_loss: 9.7257e-04
# Epoch 40/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.7283e-04 - val_loss: 9.6589e-04
# Epoch 41/50
# 171/171 [==============================] - 1s 3ms/step - loss: 9.7007e-04 - val_loss: 9.6415e-04
# Epoch 42/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.6816e-04 - val_loss: 9.6572e-04
# Epoch 43/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.6831e-04 - val_loss: 9.6818e-04
# Epoch 44/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.6513e-04 - val_loss: 9.6445e-04
# Epoch 45/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.6314e-04 - val_loss: 9.6173e-04
# Epoch 46/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.6288e-04 - val_loss: 9.5598e-04
# Epoch 47/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.6028e-04 - val_loss: 9.5528e-04
# Epoch 48/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.5727e-04 - val_loss: 9.6184e-04
# Epoch 49/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.5524e-04 - val_loss: 9.5231e-04
# Epoch 50/50
# 171/171 [==============================] - 0s 3ms/step - loss: 9.5612e-04 - val_loss: 9.5331e-04

# %%
plot_learning_curve(history)

# %% [markdown]
# #### 2) 예측 및 검증

# %% [markdown]
# * 예측

# %%
pred = model.predict(x_val)
pred
# Out:
# 188/188 [==============================] - 0s 1ms/step
# array([[0.94114155, 0.73896646, 0.62954503, ..., 0.41268808, 0.35203955,
#         0.00361632],
#        [0.9368575 , 0.7353353 , 0.6321844 , ..., 0.4138586 , 0.35217237,
#         0.00232213],
#        [0.94018865, 0.7378271 , 0.63075   , ..., 0.41421264, 0.35140795,
#         0.00293182],
#        ...,
#        [0.9355678 , 0.73107165, 0.63730645, ..., 0.4144933 , 0.3569824 ,
#         0.00188381],
#        [0.93218696, 0.7315569 , 0.6415433 , ..., 0.41409954, 0.35144863,
#         0.00419471],
#        [0.94052404, 0.73621166, 0.6331568 , ..., 0.41374758, 0.35499585,
#         0.00311416]], dtype=float32)

# %% [markdown]
# * 재구성 오차 그래프

# %%
result = recon_err_plot(x_val, pred, y_val, .03)

# %%
result.head()
# Out:
#    index  recon_err  y
# 0   9812   0.000365  0
# 1   7615   0.000716  0
# 2  14799   0.000734  0
# 3  16457   0.000395  0
# 4   6563   0.000246  0

# %% [markdown]
# * precision_recall_f1_curve

# %%
_, _, f1, thresholds = prec_rec_f1_curve(result['y'], result['recon_err'])
# Out:
# <ipython-input-3-54b2435d894a>:3: RuntimeWarning: divide by zero encountered in true_divide
#   f1 = 2 / (1/precision + 1/recall)

# %% [markdown]
# * f1을 최대화 하는 threshold 값으로 평가

# %%
thres_f1_max = thresholds[np.argmax(f1)]
thres_f1_max
# Out:
# 0.0037643288276041696

# %%
classification_report2(result['y'], result['recon_err'], thres_f1_max)
# Out:
# < confusion matrix >
#
# [[5703  144]
#  [  79   74]]
#
# ============================================================
#
# < classification_report >
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      5847
#            1       0.34      0.48      0.40       153
#
#     accuracy                           0.96      6000
#    macro avg       0.66      0.73      0.69      6000
# weighted avg       0.97      0.96      0.97      6000

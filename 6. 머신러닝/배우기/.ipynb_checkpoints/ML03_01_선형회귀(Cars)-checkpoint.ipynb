# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/speed.png?raw=true" width=800 align="left"/>

# %% [markdown]
# # 실습 내용
#
# - Cars 데이터를 불러와 살펴봅니다.
#     - 속도-제동거리 관계: (제동거리 = 브레이크 밟은 뒤 멈출때까지의 거리)
#     - 단위: 속도 = mile/h, 거리 = feet
# - 단순 선형회귀 모델을 만들고 평가합니다.
# - 특히 회귀 계수를 명확히 이해합니다.
# - 예측 결과를 시각화합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 라이브러리와 대상 데이터를 가져와 이후 과정을 준비합니다.

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %%
# 데이터 읽어오기
# path = 'https://raw.githubusercontent.com/Jangrae/csv/master/cars.csv'
path = 'https://bit.ly/CarsFile' # 강사님이 사전에 준비해둔 단축 URL
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 충분히 이해할 수 있도록 다양한 탐색 과정을 수행합니다.

# %%
# 상위 몇 개 행 확인
data.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
# 하위 몇 개 행 확인
data.tail()
# Out:
#     speed  dist
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
# 기술통계 확인
data.describe()
# Out:
#            speed        dist
# count  50.000000   50.000000
# mean   15.400000   42.980000
# std     5.287644   25.769377
# min     4.000000    2.000000
# 25%    12.000000   26.000000
# 50%    15.000000   36.000000
# 75%    19.000000   56.000000
# max    25.000000  120.000000

# %%
# NaN 값 확인
data.isnull().sum()
# Out:
# speed    0
# dist     0
# dtype: int64

# %%
# speed, dist 관계
plt.scatter(x='speed', y='dist', data=data)
plt.xlabel('Speed(mph)')
plt.ylabel('Dist(ft)')
plt.show()

# %% [markdown]
# ![image.png](attachment:affb07f3-efa9-4a9f-a1dc-f5d34f752416.png)
# - 이상치: 브레이크 살짝 밟았나?

# %% [markdown]
# # 3.데이터 준비
#
# - 전처리 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# **1) x, y 분리**
#
# - 우선 target 변수를 명확히 지정합니다.
# - target을 제외한 나머지 변수들 데이터는 x로 선언합니다.
# - target 변수 데이터는 y로 선언합니다.
# - 이 결과로 만들어진 x는 데이터프레임, y는 시리즈가 됩니다.
# - 이후 모든 작업은 x, y를 대상으로 진행합니다.

# %%
# target 확인
target = 'dist'

# 데이터 분리
x = data.drop(target, axis=1)
y = data.loc[:, target]

# %% [markdown]
# **2) 학습용, 평가용 데이터 분리**
#
# - 학습용, 평가용 데이터를 적절한 비율로 분리합니다.
# - 반복 실행 시 동일한 결과를 얻기 위해 random_state 옵션을 지정합니다.

# %%
# 모듈 불러오기
from sklearn.model_selection import train_test_split

# 7:3으로 분리
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# # 4.모델링
#
# - 본격적으로 모델을 선언하고 학습하고 평가하는 과정을 진행합니다.

# %%
# 1단계: 불러오기
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score # import * 하면 전부 import

# %% [markdown]
# mse는 제곱한 값이라 상당히 값이 크게 나오므로 고객에게 얘기하기 좀 그럼.. -> 대신 mae 쓰자

# %%
# 2단계: 선언하기
model = LinearRegression()

# %%
# 3단계: 학습하기
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 4단계: 예측하기
y_pred = model.predict(x_test)

# %%
# 5단계: 평가하기
print('mae: ', mean_absolute_error(y_test, y_pred))
print('r2-score: ', r2_score(y_test, y_pred))
# Out:
# mae:  15.113442990354987
# r2-score:  0.5548332681132087

# %% [markdown]
# - 15피트 정도의 절댓값 오차를 가지고 있으며,
# - 평균보다는 55% 정도의 설명력을 더 가지고 있음
# <br>→ 전처리 시 이상치를 제거하면 성능이 더 올라갈 것

# %% [markdown]
# - 회귀 계수를 살펴봅니다.

# %%
# 회귀계수 확인
print('가중치(기울기): ', model.coef_)
print('편향(절편): ', model.intercept_)
# Out:
# 가중치(기울기):  [3.91046344]
# 편향(절편):  -16.373364149357656

# %% [markdown]
# 회귀식
# $$\Large Distance = 3.91 * Speed - 16.37 $$
# $\Huge Distance = 3.91 * Speed - 16.37 $

# %% [markdown]
# # 5.기타
#
# - 기타 필요한 내용이 있으면 진행합니다.

# %%
# 회귀식 만들기
a = model.coef_
b = model.intercept_
speed = np.linspace(x.min(), x.max(), 10) # (이상, 이하, 개의 등간격의 숫자들을 담은 리스트 반환)
dist = a*speed + b

# %%
speed
# Out:
# array([[ 4.        ],
#        [ 6.33333333],
#        [ 8.66666667],
#        [11.        ],
#        [13.33333333],
#        [15.66666667],
#        [18.        ],
#        [20.33333333],
#        [22.66666667],
#        [25.        ]])

# %%
# 회귀선 그리기
plt.scatter(x_train, y_train, c = 'r')
plt.scatter(x_test, y_test)
plt.plot(speed, dist, color='r')
plt.axhline(y_train.mean(), c='r', linestyle='--')
plt.axhline(y_test.mean(), linestyle='--')

plt.title('Speed & Distance', size=15, pad=10) # 제목 텍스트 아래쪽 패딩
plt.xlabel('Speed(mph)')
plt.ylabel('Dist(ft)')
plt.show()

# %% [markdown]
# 위 회귀선은 평가 데이터가 아닌 학습 데이터에 대한 최선의 선임
# - But 평가 데이터에 대해서도 어느정도 맞으므로 모델이 쓸만하다는 것을 알 수 O
#
# <br>mse, mae, r2-score 등 구할때의 평균은 test-data의 평균

# %%
# 시각화
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.ylabel('Dist(ft)')
plt.show()
